# %%
import torch  # 命令行是逐行立即执行的
content = torch.load('/home/zzy/AutoFormer/out_put/checkpoint-2.pth')
print(content.keys())   # keys()
# Out:
# dict_keys(['top_accuracies', 'memory', 'candidates', 'vis_dict', 'keep_top_k', 'epoch'])

# %%
# 之后有其他需求比如要看 key 为 model 的内容有啥
for key in content.keys():
    print(f"key:{key},value:{content[key]}",end='\n')

print(len(content['top_accuracies']))
print(len(content['memory'][0]))
print('cands个数：{}'.format(len(content['candidates'])))
print('cands样例：{}'.format(content['candidates'][0]))
print(content['vis_dict'])

print('vis_dict中的cands数量：{}'.format(len(content['vis_dict'].keys())))
for key in content['vis_dict'].keys():
    print(f"key:{key},value:{content['vis_dict'][key]}",end='\n')
# Out:
# key:top_accuracies,value:[[69.99106632626925, 69.58579844891287, 69.2546969847562, 69.20152682726226, 69.11979726837606, 69.08774325222006, 69.04743988978404, 69.03672537290628, 68.88320436271405, 68.52858690187367, 67.41062113729114, 67.3764358743165, 66.94847512960668, 66.83921739471266, 65.9357058986595, 65.65894110713148, 65.60829988931548, 65.54672646122755, 65.47665554059107, 65.31336678598825, 65.30185437645414, 65.19834102201615, 64.58408045605063, 64.45987054364876, 64.24462448352212, 64.2265289378055, 64.08933803096066, 64.03763313710793, 64.03412876586818, 63.522334094219914, 63.28813185751917, 63.15528112938677, 63.13113572574588, 62.867323088001086, 62.564796746315956, 62.193245823958755, 61.98040282352787, 61.88029824421541, 61.794737714457, 61.771699558434904, 61.6655617674248, 61.589752259859445, 61.55894197780241, 61.160080634027366, 61.0997487367023, 60.98485912914444, 60.845691383757654, 60.44963240716169, 60.2403706032711, 60.00726508920538], [69.99106632626925, 6
# ...
